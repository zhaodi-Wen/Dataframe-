# %%
import pandas as pd

# %%
PATH = './120-years-of-olympic-history-athletes-and-results/athlete_events.csv'
data = pd.read_csv(PATH)
data
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %% [markdown]
# ## 1. How old were the youngest male and female participants of the 1996 Olympics?
#
#     16 and 15
#     14 and 12
#     16 and 12
#     13 and 11

# %%
youngests_male=min(data.loc[(data['Sex']=='M')&(data['Year']==1996)]['Age'])

youngests_female = min(data.loc[(data['Sex']=='F') & (data['Year']==1996)]['Age'])
print("youngets male athlete's age is ",youngests_male)
print("youngests_female athlete's age is ",youngests_female )
# Out:
# youngets male athlete's age is  14.0
# youngests_female athlete's age is  12.0

# %% [markdown]
# ## 2. What was the percentage of male gymnasts among all the male participants of the 2000 Olympics? Round the answer to the first decimal.
#
# Hint: here and further if needed drop duplicated sportsmen to count only unique ones.
#
#     0.2
#     1.5
#     2.5
#     7.7

# %%
male_athlethe = data.loc[(data['Year']==2000)&(data['Sex']=='M')]
male_athlethe
male_athlethe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8390 entries, 31 to 271108
# Data columns (total 15 columns):
# ID        8390 non-null int64
# Name      8390 non-null object
# Sex       8390 non-null object
# Age       8390 non-null float64
# Height    8310 non-null float64
# Weight    8308 non-null float64
# Team      8390 non-null object
# NOC       8390 non-null object
# Games     8390 non-null object
# Year      8390 non-null int64
# Season    8390 non-null object
# City      8390 non-null object
# Sport     8390 non-null object
# Event     8390 non-null object
# Medal     1124 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 1.0+ MB

# %%
male_athlethe = male_athlethe.drop_duplicates('Name','first')
male_gymnasts = male_athlethe.loc[male_athlethe['Sport']=='Gymnastics']
male_gymnasts.Sex.value_counts()
male_athlethe
male_gymnasts
print('ratio is {}{}'.format(male_gymnasts.Sex.value_counts()/male_athlethe.Sex.value_counts()*100,'%'))
# Out:
# ratio is M    1.475061
# Name: Sex, dtype: float64%

# %% [markdown]
# ## 3. What are the mean and standard deviation of height for female basketball players participated in the 2000 Olympics? Round the answer to the first decimal.
#
#     178.5 and 7.2
#     179.4 and 10
#     180.7 and 6.7
#     182.4 and 9.1

# %%
female_athlethe = data.loc[(data['Year']==2000)&(data['Sex']=='F')&(data['Sport']=='Basketball')]
female_athlethe
female_athlethe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142 entries, 1034 to 270060
# Data columns (total 15 columns):
# ID        142 non-null int64
# Name      142 non-null object
# Sex       142 non-null object
# Age       142 non-null float64
# Height    142 non-null float64
# Weight    142 non-null float64
# Team      142 non-null object
# NOC       142 non-null object
# Games     142 non-null object
# Year      142 non-null int64
# Season    142 non-null object
# City      142 non-null object
# Sport     142 non-null object
# Event     142 non-null object
# Medal     35 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 17.8+ KB

# %%
import numpy as np
female_basketball_height_mean = np.mean(female_athlethe['Height'])
female_basketball_height_std  = np.std(female_athlethe['Height'])
print("mean of height is :",female_basketball_height_mean)
print("std of height is :",female_basketball_height_std)
# Out:
# mean of height is : 182.38732394366198
# std of height is : 9.10722402592803

# %% [markdown]
# ## 4. Find a sportsperson participated in the 2002 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?
#
#     Judo
#     Bobsleigh
#     Weightlifting
#     Boxing

# %%
athlethe = data.loc[(data['Year']==2002)]
sports = athlethe.loc[athlethe['Weight']==max(athlethe["Weight"])]
sports
# Out:
#           ID               Name Sex   Age  Height  Weight    Team  NOC  \
# 99154  50171  Emmanuel Hostache   M  26.0   190.0   123.0  France  FRA
#
#              Games  Year  Season            City      Sport  \
# 99154  2002 Winter  2002  Winter  Salt Lake City  Bobsleigh
#
#                      Event Medal
# 99154  Bobsleigh Men's Two   NaN

# %% [markdown]
# ## 5. How many times did Pawe Abratkiewicz participate in the Olympics held in different years?
#
#     0
#     1
#     2
#     3

# %%
Pawe_Abratkiewicz_tabel = data.loc[data['Name']=='Pawe Abratkiewicz']
Pawe_Abratkiewicz_tabel = Pawe_Abratkiewicz_tabel.drop_duplicates('Year','first')
Pawe_Abratkiewicz_tabel.Sex.value_counts()
# Out:
# M    3
# Name: Sex, dtype: int64

# %% [markdown]
# ## 6. How many silver medals in tennis did Australia win at the 2000 Olympics?
#
#     0
#     1
#     2
#     3

# %%
australia_tennis_table = data.loc[(data['Sport']=='Tennis')&(data['Year']==2000)&(data['Team']=='Australia')&(data['Medal']=='Silver')]
australia_tennis_table
# Out:
#             ID                    Name Sex   Age  Height  Weight       Team  \
# 262820  131504  Todd Andrew Woodbridge   M  29.0   178.0    75.0  Australia
# 262831  131511  Mark Raymond Woodforde   M  34.0   183.0    80.0  Australia
#
#         NOC        Games  Year  Season    City   Sport                 Event  \
# 262820  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
# 262831  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
#
#          Medal
# 262820  Silver
# 262831  Silver

# %% [markdown]
# ## 7. Is it true that Switzerland won fewer medals than Serbia at the 2016 Olympics? Do not consider NaN values in Medal column.
#
#     Yes
#     No

# %%
Switzerland_medals_tabel = data.loc[(data['Team']=='Switzerland')&(data['Year']==2016)]
Serbia_modals_tabel = data.loc[(data['Team']=='Serbia')&(data['Year']==2016)]
print(Switzerland_medals_tabel.info())
print(Serbia_modals_tabel.info())
Switzerland_medals_tabel.Medal.notnull().value_counts()
Serbia_modals_tabel.Medal.notnull().value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148 entries, 894 to 266926
# Data columns (total 15 columns):
# ID        148 non-null int64
# Name      148 non-null object
# Sex       148 non-null object
# Age       148 non-null float64
# Height    148 non-null float64
# Weight    148 non-null float64
# Team      148 non-null object
# NOC       148 non-null object
# Games     148 non-null object
# Year      148 non-null int64
# Season    148 non-null object
# City      148 non-null object
# Sport     148 non-null object
# Event     148 non-null object
# Medal     11 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 18.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127 entries, 4417 to 270371
# Data columns (total 15 columns):
# ID        127 non-null int64
# Name      127 non-null object
# Sex       127 non-null object
# Age       127 non-null float64
# Height    127 non-null float64
# Weight    127 non-null float64
# ...

# %% [markdown]
# ## 8. What age category did the fewest and the most participants of the 2014 Olympics belong to?
#
#     [45-55] and [25-35) correspondingly
#     [45-55] and [15-25) correspondingly
#     [35-45) and [25-35) correspondingly
#     [45-55] and [35-45) correspondingly

# %%
athlete_2014 = data.loc[data['Year']==2014]
#athlete_2014.info()

age_15_25 = len(athlete_2014.loc[(15<=athlete_2014.Age)&(athlete_2014.Age<25)])
age_25_35 = len(athlete_2014.loc[(25<=athlete_2014.Age)&(athlete_2014.Age<35)])
age_35_45 = len(athlete_2014.loc[(35<=athlete_2014.Age)&(athlete_2014.Age<45)])
age_45_55 = len(athlete_2014.loc[(45<=athlete_2014.Age)&(athlete_2014.Age<=55)])
print(age_15_25)
print(age_25_35)
print(age_35_45)
print(age_45_55)
# Out:
# 2027
# 2594
# 265
# 5

# %% [markdown]
# ## 9. Is it true that there were Summer Olympics held in Lake Placid? Is it true that there were Winter Olympics held in Sankt Moritz?
#
#     Yes, Yes
#     Yes, No
#     No, Yes
#     No, No

# %%
Lake_Placid = data.loc[(data['City']=='Lake Placid')&(data.Season=='Summer')]
print(len(Lake_Placid))
Sankt_Moritz = data.loc[(data['City']=='Sankt Moritz')&(data.Season=='Winter')]
Sankt_Moritz = Sankt_Moritz.drop_duplicates('Year','first')
print(len(Sankt_Moritz))
# Out:
# 0
# 2

# %% [markdown]
# ## 10. What is the absolute difference between the number of unique sports at the 1995 Olympics and 2016 Olympics?
#
#     16
#     24
#     26
#     34

# %%
sports_2016 = data.loc[data['Year']==2016]
sports_1995 = data.loc[data['Year']==1995]
sports_2016 = len(sports_2016.drop_duplicates('Sport','first'))
sports_1995 = len(sports_1995.drop_duplicates('Sport','first'))
print(abs(sports_1995-sports_2016))
# Out:
# 34
